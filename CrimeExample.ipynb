# %% [markdown]
# <a href="https://colab.research.google.com/github/debora28/projetoPi_2020-1/blob/master/CrimeExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando bibliotecas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Após carregar o arquivo diretamente no notebook Colab:

# %%
mydata = pd.read_csv('crimeExample.csv')

# %% [markdown]
# Descrevendo os dados e obtendo gráficos:

# %%
mydata.describe(include="all")
# Out:
#           Dc_Dist  Psa   Dispatch_Date_Time  ...    Month        Lon        Lat
# count   99.000000   99                   99  ...       99  55.000000  55.000000
# unique        NaN   18                   99  ...       25        NaN        NaN
# top           NaN    1  2006-08-23 20:07:00  ...  2015-05        NaN        NaN
# freq          NaN   25                    1  ...        8        NaN        NaN
# mean    23.989899  NaN                  NaN  ...      NaN -75.163732  39.977213
# std     20.162855  NaN                  NaN  ...      NaN   0.054031   0.037464
# min      1.000000  NaN                  NaN  ...      NaN -75.266605  39.883852
# 25%     15.000000  NaN                  NaN  ...      NaN -75.200853  39.956089
# 50%     19.000000  NaN                  NaN  ...      NaN -75.169577  39.975197
# 75%     24.000000  NaN                  NaN  ...      NaN -75.132915  40.001119
# max     92.000000  NaN                  NaN  ...      NaN -75.032986  40.055312
#
# [11 rows x 14 columns]

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Dc_Dist             99 non-null     int64
#  1   Psa                 99 non-null     object
#  2   Dispatch_Date_Time  99 non-null     object
#  3   Dispatch_Date       99 non-null     object
#  4   Dispatch_Time       99 non-null     object
#  5   Hour                99 non-null     int64
#  6   Dc_Key              99 non-null     int64
#  7   Location_Block      99 non-null     object
#  8   UCR_General         99 non-null     int64
#  9   Text_General_Code   99 non-null     object
#  10  Police_Districts    55 non-null     float64
#  11  Month               99 non-null     object
#  12  Lon                 55 non-null     float64
#  13  Lat                 55 non-null     float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 11.0+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3309145f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa33084f4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3344289b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa31fd62240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa31ff8b4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa31ffa7710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32c191978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa329211ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa329211c18>]],
#       dtype=object)

# %%
import seaborn as sns

# %%
sns.pairplot(mydata)

# %%
#Gerando histogramas com dimensões contínuas e categoricas 
mydata.hist(by='Text_General_Code',column = 'Month')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fd0f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fc7f9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fc067f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fc2db70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fbdeef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fb9b2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fb4c630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fafd978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fafd9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32faf10f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32faa2470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fa557f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fa06b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32fa39ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f9f72b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f9aa630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f95b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f90dd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f8cd0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa32f87e470>]],
#       dtype=object)

# %%
# Calculando Correlação
# Quanto mais próximo de 1: Diretamente relacionado
# Quanto mais próximo de -1: Inversamente relacionado
corr = mydata.corr()
corr
# Out:
#                    Dc_Dist      Hour  ...       Lon       Lat
# Dc_Dist           1.000000  0.144359  ... -0.288499 -0.254182
# Hour              0.144359  1.000000  ...  0.067949  0.078571
# Dc_Key           -0.285337  0.006228  ... -0.046871 -0.096683
# UCR_General       0.108115 -0.110684  ... -0.005893  0.052936
# Police_Districts  0.829339 -0.073941  ... -0.354122 -0.147014
# Lon              -0.288499  0.067949  ...  1.000000  0.654268
# Lat              -0.254182  0.078571  ...  0.654268  1.000000
#
# [7 rows x 7 columns]

# %%
# Gerando uma matriz de correlação
# Perceba que quanto mais claro: Diretamente proporcional
# Perceba que quanto mais escuro: Inversamente proporcional
sns.heatmap(corr, annot=True)
